# %% [markdown]
# <h4> Import Dependencies </h4>

# %%
import os
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
from pprint import pprint
import sqlite3
import csv

# API keys
from config import api_key

# %% [markdown]
# <h2>Financial Data, API Exctraction</h2>

# %% [markdown]
# <h4>Make API Calls and Populate a DataFrame</h4>

# %%
#Starting Year
year = 2000

# %%
#API url path
url = f"https://api.open.fec.gov/v1/elections/?api_key={api_key}&sort=-total_receipts&sort_hide_null=false&office=president&election_full=true&sort_null_only=false&cycle={year}&sort_nulls_last=false&page=1"

# read data from the API 
response = requests.get(url).json()
# pprint(response)

# convert JSON to dataframe
candidate_finance = pd.json_normalize(response, "results")
# print(candidate_finance.shape)

#Append following year data to existing DataFrame
for yr in range(year + 4, 2017, 4):
    url = f"https://api.open.fec.gov/v1/elections/?api_key={api_key}&sort=-total_receipts&sort_hide_null=false&office=president&election_full=true&sort_null_only=false&cycle={yr}&sort_nulls_last=false&page=1"
    response = requests.get(url).json()
   
    sub_df = pd.json_normalize(response, "results")
    candidate_finance.head(2)
#     print(f"{yr} {type(sub_df)}  ================================")
    candidate_finance = candidate_finance.append(sub_df, ignore_index=True)
    
# Format dataframe
candidate_finance = candidate_finance[['candidate_election_year', 'candidate_id', 'candidate_name', 'party_full', 'total_receipts', 'total_disbursements', 'cash_on_hand_end_period']]
candidate_finance.style.format({"total_receipts": '${0:,.2f}',
                                "total_disbursements": '${0:,.2f}',
                                "cash_on_hand_end_period": '${0:,.2f}',})

candidate_finance["candidate_name"]
pprint(response)
# Out:
# {'api_version': '1.0',
#  'pagination': {'count': 669, 'page': 1, 'pages': 34, 'per_page': 20},
#  'results': [{'candidate_election_year': 2016,
#               'candidate_id': 'P00003392',
#               'candidate_name': 'CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL '
#                                 'KAINE',
#               'candidate_pcc_id': 'C00575795',
#               'candidate_pcc_name': 'HILLARY FOR AMERICA',
#               'cash_on_hand_end_period': 323317.48,
#               'committee_ids': ['C00431569', 'C00575795'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'DEMOCRATIC PARTY',
#               'total_disbursements': 585580576.76,
#               'total_receipts': 585699061.27},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P80001571',
#               'candidate_name': 'TRUMP, DONALD J. / MICHAEL R. PENCE ',
#               'candidate_pcc_id': 'C00580100',
#               'candidate_pcc_name': 'DONALD J. TRUMP FOR PRESIDENT, INC.',
#               'cash_on_hand_end_period': 7611702.92,
#               'committee_ids': ['C00580100'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 343056732.78,
#               'total_receipts': 350668435.7},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60007168',
#               'candidate_name': 'SANDERS, BERNARD',
#               'candidate_pcc_id': 'C00577130',
#               'candidate_pcc_name': 'BERNIE 2016',
#               'cash_on_hand_end_period': 5455167.9,
#               'committee_ids': ['C00577130'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'DEMOCRATIC PARTY',
#               'total_disbursements': 232185441.62,
#               'total_receipts': 237640609.52},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60006111',
#               'candidate_name': 'CRUZ, RAFAEL EDWARD "TED"',
#               'candidate_pcc_id': 'C00574624',
#               'candidate_pcc_name': 'CRUZ FOR PRESIDENT',
#               'cash_on_hand_end_period': 33851.52,
#               'committee_ids': ['C00574624'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 94304803.32,
#               'total_receipts': 94338654.84},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60005915',
#               'candidate_name': 'CARSON, BENJAMIN S SR MD',
#               'candidate_pcc_id': 'C00573519',
#               'candidate_pcc_name': 'CARSON AMERICA',
#               'cash_on_hand_end_period': 560750.51,
#               'committee_ids': ['C00573519'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 64530285.46,
#               'total_receipts': 65091035.97},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60006723',
#               'candidate_name': 'RUBIO, MARCO',
#               'candidate_pcc_id': 'C00458844',
#               'candidate_pcc_name': 'MARCO RUBIO FOR PRESIDENT',
#               'cash_on_hand_end_period': 112614.3,
#               'committee_ids': ['C00458844'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 51557701.76,
#               'total_receipts': 48331861.99},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60008059',
#               'candidate_name': 'BUSH, JEB',
#               'candidate_pcc_id': 'C00579458',
#               'candidate_pcc_name': 'JEB 2016, INC.',
#               'cash_on_hand_end_period': 55306.05,
#               'committee_ids': ['C00579458'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 35435885.43,
#               'total_receipts': 35491191.48},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60003670',
#               'candidate_name': 'KASICH, JOHN R',
#               'candidate_pcc_id': 'C00581876',
#               'candidate_pcc_name': 'KASICH FOR AMERICA, INC.',
#               'cash_on_hand_end_period': 158566.66,
#               'committee_ids': ['C00581876'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 19534124.57,
#               'total_receipts': 19692691.23},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P40003576',
#               'candidate_name': 'PAUL, RAND',
#               'candidate_pcc_id': 'C00575449',
#               'candidate_pcc_name': 'FREEDOM FOR ALL AMERICANS',
#               'cash_on_hand_end_period': 6492.92,
#               'committee_ids': ['C00575449'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 12452499.19,
#               'total_receipts': 12458992.11},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60007242',
#               'candidate_name': 'FIORINA, CARLY',
#               'candidate_pcc_id': 'C00577312',
#               'candidate_pcc_name': 'CARLY FOR PRESIDENT',
#               'cash_on_hand_end_period': 799587.44,
#               'committee_ids': ['C00577312'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 11412309.97,
#               'total_receipts': 12211897.41},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P20002671',
#               'candidate_name': 'JOHNSON, GARY / WILLIAM "BILL" WELD',
#               'candidate_pcc_id': 'C00605568',
#               'candidate_pcc_name': 'GARY JOHNSON 2016',
#               'cash_on_hand_end_period': 6299.61,
#               'committee_ids': ['C00495622', 'C00605568'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'LIBERTARIAN PARTY',
#               'total_disbursements': 12463110.51,
#               'total_receipts': 12193984.08},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P20003984',
#               'candidate_name': 'STEIN, JILL',
#               'candidate_pcc_id': 'C00581199',
#               'candidate_pcc_name': 'JILL STEIN FOR PRESIDENT',
#               'cash_on_hand_end_period': 127251.43,
#               'committee_ids': ['C00505800', 'C00581199'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'GREEN PARTY',
#               'total_disbursements': 11513810.03,
#               'total_receipts': 11499548.55},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60006046',
#               'candidate_name': 'WALKER, SCOTT',
#               'candidate_pcc_id': 'C00580480',
#               'candidate_pcc_name': 'SCOTT WALKER INC',
#               'cash_on_hand_end_period': 71869.96,
#               'committee_ids': ['C00580480'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 9438000.85,
#               'total_receipts': 9509870.81},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60008521',
#               'candidate_name': 'CHRISTIE, CHRISTOPHER J',
#               'candidate_pcc_id': 'C00580399',
#               'candidate_pcc_name': 'CHRIS CHRISTIE FOR PRESIDENT INC',
#               'cash_on_hand_end_period': 27656.58,
#               'committee_ids': ['C00580399'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 8742632.18,
#               'total_receipts': 8770288.76},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60016342',
#               'candidate_name': 'DE  LA  FUENTE, ROQUE ROCKY',
#               'candidate_pcc_id': 'C00588426',
#               'candidate_pcc_name': 'ROCKY 101 LLC',
#               'cash_on_hand_end_period': 1046.08,
#               'committee_ids': ['C00588426'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'DEMOCRATIC PARTY',
#               'total_disbursements': 8074913.65,
#               'total_receipts': 8075959.73},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60007671',
#               'candidate_name': "O'MALLEY, MARTIN JOSEPH",
#               'candidate_pcc_id': 'C00578658',
#               'candidate_pcc_name': "O'MALLEY FOR PRESIDENT",
#               'cash_on_hand_end_period': 92368.71,
#               'committee_ids': ['C00578658'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'DEMOCRATIC PARTY',
#               'total_disbursements': 6285181.71,
#               'total_receipts': 6377550.42},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60007697',
#               'candidate_name': 'GRAHAM, LINDSEY O',
#               'candidate_pcc_id': 'C00578757',
#               'candidate_pcc_name': 'LINDSEY GRAHAM 2016',
#               'cash_on_hand_end_period': 0.0,
#               'committee_ids': ['C00578757'],
#               'coverage_end_date': '2016-09-20T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 6010010.2,
#               'total_receipts': 6010010.2},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P80003478',
#               'candidate_name': 'HUCKABEE, MIKE',
#               'candidate_pcc_id': 'C00577981',
#               'candidate_pcc_name': 'HUCKABEE FOR PRESIDENT, INC.',
#               'cash_on_hand_end_period': 5557.58,
#               'committee_ids': ['C00577981'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 4330417.8,
#               'total_receipts': 4335975.38},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P20002721',
#               'candidate_name': 'SANTORUM, RICHARD J.',
#               'candidate_pcc_id': 'C00578492',
#               'candidate_pcc_name': 'SANTORUM FOR PRESIDENT 2016',
#               'cash_on_hand_end_period': 110242.76,
#               'committee_ids': ['C00496034', 'C00578492'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'REPUBLICAN PARTY',
#               'total_disbursements': 2312075.09,
#               'total_receipts': 2296044.14},
#              {'candidate_election_year': 2016,
#               'candidate_id': 'P60022654',
#               'candidate_name': 'MCMULLIN, EVAN / MINDY FINN',
#               'candidate_pcc_id': 'C00623884',
#               'candidate_pcc_name': 'MCMULLIN FOR PRESIDENT COMMITTEE INC.',
#               'cash_on_hand_end_period': 1936.33,
#               'committee_ids': ['C00623884'],
#               'coverage_end_date': '2016-12-31T00:00:00',
#               'incumbent_challenge_full': 'Open seat',
#               'party_full': 'INDEPENDENT',
#               'total_disbursements': 1642165.87,
#               'total_receipts': 1644102.2}]}

# %% [markdown]
# <h4>Clean Data</h4>

# %%
def rename(name):
    #Some names are in format: Pres / Vice Pres - we only want President name
    name = name.split("/")[0]
    #President name in Last, First MI. format - we want First MI Last
    name_components = name.split(",")
    new_name = name_components[-1] + " " + name_components[0]
    return new_name.upper().strip()

#Apply the renaming funtion to the dataframe
candidate_finance["candidate_name"] = candidate_finance["candidate_name"].apply(rename)
candidate_finance
# Out:
#     candidate_election_year candidate_id          candidate_name  \
# 0                      2000    P00003335           GEORGE W BUSH
# 1                      2000    P80000912                 AL GORE
# 2                      2000    P60003852            STEVE FORBES
# 3                      2000    P80002801           JOHN S MCCAIN
# 4                      2000    P80000516            BILL BRADLEY
# ..                      ...          ...                     ...
# 95                     2016    P60007671  MARTIN JOSEPH O'MALLEY
# 96                     2016    P60007697        LINDSEY O GRAHAM
# 97                     2016    P80003478           MIKE HUCKABEE
# 98                     2016    P20002721     RICHARD J. SANTORUM
# 99                     2016    P60022654          EVAN  MCMULLIN
#
#           party_full  total_receipts  total_disbursements  \
# 0   REPUBLICAN PARTY    1.936577e+08         1.864560e+08
# 1   DEMOCRATIC PARTY    1.331080e+08         1.203352e+08
# 2   REPUBLICAN PARTY    8.604857e+07         8.605477e+07
# 3   REPUBLICAN PARTY    5.863623e+07         5.854997e+07
# 4   DEMOCRATIC PARTY    5.115617e+07         5.042141e+07
# ..               ...             ...                  ...
# 95  DEMOCRATIC PARTY    6.377550e+06         6.285182e+06
# 96  REPUBLICAN PARTY    6.010010e+06         6.010010e+06
# 97  REPUBLICAN PARTY    4.335975e+06         4.330418e+06
# 98  REPUBLICAN PARTY    2.296044e+06         2.312075e+06
# 99       INDEPENDENT    1.644102e+06         1.642166e+06
#
#     cash_on_hand_end_period
# 0                7201734.18
# 1               12772827.00
# 2                      0.00
# 3                  86262.00
# 4                 775203.00
# ..                      ...
# 95                 92368.71
# 96                     0.00
# 97                  5557.58
# 98                110242.76
# 99                  1936.33
#
# [100 rows x 7 columns]

# %% [markdown]
# <h2>Election Result Data, CSV Extraction</h2>

# %% [markdown]
# <h4>Read CSV and Populate a DataFrame</h4>

# %%
election_csv = f"{year}_PopularVote.csv"



path = os.path.join("Resources", election_csv)
election_df = pd.read_csv(path, encoding="ISO-8859-1")

# %% [markdown]
# <h4>Clean Data</h4>

# %%
election_df = election_df.rename(columns = {
    "Candidate (Party Label)": "name"
})
election_df = election_df[["name", "Popular Vote Total", "Percent of Popular Vote"]]
election_df["year"] = 2000
election_df = election_df.dropna()

def conv_name(long_name):
    #Some data in FOrmat Name (Party) - we just want name
    short_name = long_name.split('(')[0]
    #MI is followed by ".", we want to remove that
    short_name = short_name.replace('.', '')
    return short_name.upper().strip()

#apply the name cleaning to the dataframe
election_df["name"] = election_df["name"].apply(conv_name)
election_df.head(100)
# Out:
#                         name Popular Vote Total  Percent of Popular Vote  year
# 1                    AL GORE         50,999,897                    48.38  2000
# 2              GEORGE W BUSH         50,456,002                    47.87  2000
# 3                RALPH NADER          2,882,955                     2.74  2000
# 4         PATRICK J BUCHANAN            448,895                     0.42  2000
# 5               HARRY BROWNE            384,431                     0.36  2000
# 6            HOWARD PHILLIPS             98,020                     0.09  2000
# 7             JOHN S HAGELIN             83,714                     0.08  2000
# 8                   WRITE-IN             20,767                     0.02  2000
# 9         JAMES E HARRIS, JR              7,378                     0.01  2000
# 10              L NEIL SMITH              5,775                     0.00  2000
# 11          DAVID MCREYNOLDS              5,602                     0.00  2000
# 12          MONICA MOOREHEAD              4,795                     0.00  2000
# 13  NONE OF THESE CANDIDATES              3,315                     0.00  2000
# 14        CATHY GORDON BROWN              1,606                     0.00  2000
# 15                DENNY LANE              1,044                     0.00  2000
# 16            RANDALL VENSON                535                     0.00  2000
# 17              EARL F DODGE                208                     0.00  2000
# 18         LOUIE G YOUNGKEIT                161                     0.00  2000

# %% [markdown]
# <h4>Append folling year data to DataFrame</h4?

# %%
for yr in range(year + 4, 2017, 4):
    path = os.path.join("Resources", f"{yr}_PopularVote.csv")
    temp_df = pd.read_csv(path, encoding="ISO-8859-1")
    if yr == 2004: #2004 data is formatted differently
        temp_df = temp_df.rename(columns = {
            "Candidate": "name"
        })
        temp_df = temp_df[["name", "Popular Vote Total", "Percent of Popular Vote"]]
        temp_df = temp_df.dropna()
        temp_df["name"] = temp_df["name"].apply(conv_name)
        temp_df["year"] = yr
        election_df = election_df.append(temp_df, ignore_index=True)

    else:
        temp_df = temp_df.rename(columns = {
            "Candidate (Party Label)": "name"
        })
        temp_df = temp_df[["name", "Popular Vote Total", "Percent of Popular Vote"]]
        temp_df = temp_df.dropna()
        temp_df["name"] = temp_df["name"].apply(conv_name)
        temp_df["year"] = yr
        election_df = election_df.append(temp_df, ignore_index=True)
        election_df = election_df.dropna()

election_df = election_df.rename(columns = {"name": "Name", "Popular Vote Total": "Votes", "Percent of Popular Vote": "VotePct"})

df = pd.DataFrame(election_df)
df.head(100)
# Out:
#                   Name       Votes VotePct  year
# 0              AL GORE  50,999,897   48.38  2000
# 1        GEORGE W BUSH  50,456,002   47.87  2000
# 2          RALPH NADER   2,882,955    2.74  2000
# 3   PATRICK J BUCHANAN     448,895    0.42  2000
# 4         HARRY BROWNE     384,431    0.36  2000
# ..                 ...         ...     ...   ...
# 95        GARY JOHNSON   4,489,341   3.28%  2016
# 96          JILL STEIN   1,457,218   1.07%  2016
# 97       EVAN MCMULLIN     731,991   0.54%  2016
# 98            WRITE-IN     698,990   0.51%  2016
# 99    DARRELL L CASTLE     203,090   0.15%  2016
#
# [100 rows x 4 columns]

# %%
df.to_csv("popular_votes_years.csv")
df.to_json("popular_votes_years.json")

# %% [markdown]
# <h2>Store DataFrames into SQL Database Tables</h2>

# %%
conn = sqlite3.connect('ETL_project.db')
c = conn.cursor()

c.execute("DROP TABLE IF EXISTS Finance")
c.execute('CREATE TABLE Finance (candidate_election_year number, candidate_id text, candidate_name text, party_full text, total_receipts number, total_disbursements number, cash_on_hand_end_period number)')
conn.commit()

candidate_finance.to_sql('Finance', conn, if_exists='replace', index = False)


c.execute("SELECT * FROM Finance WHERE candidate_election_year = 2012")

print("=========================")
print("Financial Data for 2012")
for row in c.fetchall():
    print (row)
################################################################
c.execute("DROP TABLE IF EXISTS Votes")
c.execute('CREATE TABLE Votes (Name text, Votes int, VotePct text, year int)')
conn.commit()

election_df.to_sql('Votes', conn, if_exists='replace', index = False)



c.execute("SELECT * FROM Votes WHERE year = 2012")



print("=========================")
print("Vote Data for 2012")
for row in c.fetchall():
    print (row)
# Out:
# =========================
# Financial Data for 2012
# (2012, 'P80003338', 'BARACK OBAMA', 'DEMOCRATIC PARTY', 742601913.88, 757574968.34, 3299312.93)
# (2012, 'P80003353', 'MITT  ROMNEY', 'REPUBLICAN PARTY', 483642897.19, 483292209.77, 383275.27)
# (2012, 'P80000748', 'RON PAUL', 'REPUBLICAN PARTY', 41064074.11, 40495369.56, 1147671.75)
# (2012, 'P60003654', 'NEWT GINGRICH', 'REPUBLICAN PARTY', 24976120.46, 24900556.09, 75564.37)
# (2012, 'P20002721', 'RICHARD J. SANTORUM', 'REPUBLICAN PARTY', 23552730.52, 23426456.81, 126273.71)
# (2012, 'P20003281', 'JAMES R (RICK) PERRY', 'REPUBLICAN PARTY', 20593581.15, 20199068.69, 394512.46)
# (2012, 'P00003608', 'HERMAN CAIN', 'REPUBLICAN PARTY', 16917976.94, 16913859.48, 4117.46)
# (2012, 'P20002184', 'RAPHAEL HERMAN', 'DEMOCRATIC PARTY', 16414018.0, 16414018.0, 0.0)
# (2012, 'P20003067', 'JON HUNTSMAN', 'REPUBLICAN PARTY', 9173365.13, 9173365.13, 0.0)
# (2012, 'P20002556', 'TIMOTHY PAWLENTY', 'REPUBLICAN PARTY', 5965502.16, 5965502.16, 0.0)
# (2012, 'P20002671', 'GARY EARL JOHNSON', 'LIBERTARIAN PARTY', 2796591.1, 2752658.16, 43932.94)
# (2012, 'P20003984', 'JILL STEIN', 'GREEN PARTY', 1263540.87, 1122027.96, 141512.91)
# (2012, 'P20002523', "CHARLES E. ''BUDDY'' III ROEMER", 'OTHER', 780900.91, 739453.36, 41447.55)
# (2012, 'P20002564', 'FRED KARGER', 'REPUBLICAN PARTY', 588437.17, 591271.9, 0.0)
# (2012, 'P20003109', 'THADDEUS G MCCOTTER', 'REPUBLICAN PARTY', 550437.19, 549822.09, 615.1)
# (2012, 'P20002424', 'RANDALL A TERRY', 'INDEPENDENT', 509814.27, 502083.04, 7731.23)
# (2012, 'P20002325', 'L JOHN JR DAVIS', 'REPUBLICAN PARTY', 444348.88, 444348.17, 0.0)
# (2012, 'P20004685', 'VIRGIL H JR GOODE', 'CONSTITUTION PARTY', 202258.22, 202253.35, 4.87)
# (2012, 'P20003885', 'JOHN DAVIS HAYWOOD', 'DEMOCRATIC PARTY', 135395.91, 135395.29, 2181.68)
# (2012, 'P80003114', 'JOHN DOUGLAS BLYTH', 'INDEPENDENT', 109987.24, 123973.24, 0.0)
# =========================
# Vote Data for 2012
# ('BARACK OBAMA', '65,915,795', '51.06%', 2012)
# ('MITT ROMNEY', '60,933,504', '47.20%', 2012)
# ('GARY JOHNSON', '1,275,971', '0.99%', 2012)
# ('JILL STEIN', '469,627', '0.36%', 2012)
# ('WRITE-IN', '136,040', '0.11%', 2012)
# ('VIRGIL GOODE', '122,389', '0.09%', 2012)
# ('ROSEANN BARR', '67,326', '0.05%', 2012)
# ('ROSS C "ROCKY" ANDERSON', '43,018', '0.03%', 2012)
# ('TOM HOEFLING', '40,628', '0.03%', 2012)
# ('RANDALL TERRY', '13,107', '0.01%', 2012)
# ('RICHARD DUNCAN', '12,557', '0.01%', 2012)
# ('PETA LINDSAY', '7,791', '0.01%', 2012)
# ('NONE OF THESE CANDIDATES', '5,770', '0.00%', 2012)
# ('CHUCK BALDWIN', '5,017', '0.00%', 2012)
# ('WILL CHRISTENSEN', '4,453', '0.00%', 2012)
# ('STEWART ALEXANDER', '4,405', '0.00%', 2012)
# ('JAMES HARRIS', '4,117', '0.00%', 2012)
# ('THOMAS ROBERT STEVENS', '4,091', '0.00%', 2012)
# ('JIM CARLSON', '3,149', '0.00%', 2012)
# ('JILL REED', '2,877', '0.00%', 2012)
# ('MERLIN MILLER', '2,701', '0.00%', 2012)
# ('SHEILA "SAMM" TITTLE', '2,572', '0.00%', 2012)
# ('GLORIA LA RIVA', '1,608', '0.00%', 2012)
# ('JERRY WHITE', '1,279', '0.00%', 2012)
# ('DEAN MORSTAD', '1,094', '0.00%', 2012)
# ('JERRY LITZEL', '1,027', '0.00%', 2012)
# ('BARBARA DALE WASHER', '1,016', '0.00%', 2012)
# ('JEFF BOSS', '1,007', '0.00%', 2012)
# ('ANDRE BARNETT', '956', '0.00%', 2012)
# ('JACK FELLURE', '518', '0.00%', 2012)

# %% [markdown]
# <h4>Practice putting SQL back into Dataframe</h4>

# %%
c.execute('''  
SELECT candidate_name, votes, year
FROM Finance
INNER JOIN Votes ON Finance.candidate_name = Votes.Name AND candidate_election_year = year
WHERE Finance.candidate_election_year = 2012
;
          ''')

# max_receipts = pd.DataFrame   
results = pd.DataFrame(c.fetchall(), columns=['candidate_name', "total_receipts", "year"]) 
results.head(50)
# Out:
#   candidate_name total_receipts  year
# 0   BARACK OBAMA     65,915,795  2012
# 1     JILL STEIN        469,627  2012
